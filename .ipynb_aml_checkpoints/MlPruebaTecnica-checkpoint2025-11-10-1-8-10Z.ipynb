# %% [markdown]
# # **Cuadernillo De Machine Learning**

# %%
import pandas as pd
# Out:
# StatementMeta(db5dabd3-f48a-4e56-9c04-d855362c2146, 1, 6, Finished, Available, Finished)

# %%
pd.read_csv("X.csv")
pd.read_csv("X.csv")
pd.read_csv("X.csv")
dfx = pd.read_csv('X.csv')
dfy = pd.read_csv('Y.csv')
dfz = pd.read_csv('Z.csv')
# Out:
# StatementMeta(db5dabd3-f48a-4e56-9c04-d855362c2146, 1, 7, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dfx = pd.read_csv('X.csv')
#       2 dfy = pd.read_csv('Y.csv')
#       3 dfz = pd.read_csv('Z.csv')
#
# File ~/cluster-env/env/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/cluster-env/env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
# Cargar archivo CSV desde uploads
df = pd.read_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/<cluster-id>/code/materias_primas.csv')

# Mostrar datos originales
df.head()

# %%
import os

for root, dirs, files in os.walk('/', topdown=True):
    if 'materias_primas' in root.lower():
        print(root)
        print(files)
